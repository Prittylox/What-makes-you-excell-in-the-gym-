# %%
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
dtype={'Name':str,'Sex':str,'Event':str,'Equipment':str,'Age':str,'AgeClass':str,'BirthYearClass':str,'Division':str,'BodyweightKg':str,'WeightClassKg':str,'Squat1Kg':str,'Squat2Kg':str,'Squat3Kg':str,'Squat4Kg':str,'Best3SquatKg':str,'Bench1Kg':str,'Bench2Kg':str,'Bench3Kg':str,'Bench4Kg':str,'Best3BenchKg':str,'Deadlift1Kg':str,'Deadlift2Kg':str,'Deadlift3Kg':str,'Deadlift4Kg':str,'Best3DeadliftKg':str,'TotalKg':str,'Place':str,'Dots':str,'Wilks':str,'Glossbrenner':str,'Goodlift':str,'Tested':str,'Country':str,'State':str,'Federation':str,'ParentFederation':str,'Date':str,'MeetCountry':str,'MeetState':str,'MeetTown':str,'MeetName':str}

# %%
PL = pd.read_csv ('/Users/zoe/Downloads/Data_set.csv')
# Out:
# /var/folders/r8/sb0l058j0r5_sh7jvqgwwn_40000gn/T/ipykernel_3331/3844333214.py:1: DtypeWarning: Columns (33,38) have mixed types. Specify dtype option on import or set low_memory=False.
#   PL = pd.read_csv ('/Users/zoe/Downloads/Data_set.csv')

# %%
PL.head()
# Out:
#              Name Sex Event   Equipment   Age AgeClass BirthYearClass  \
# 0   Karen Thomson   F   SBD  Single-ply  39.5    35-39          40-49
# 1  Deborah Groves   F   SBD  Single-ply  30.5    24-34          24-39
# 2     Renee Orbon   F   SBD  Single-ply  31.5    24-34          24-39
# 3  Rikki Flanders   F   SBD  Single-ply  31.5    24-34          24-39
# 4  Julie Hallmond   F   SBD  Single-ply   NaN      NaN          50-59
#
#     Division  BodyweightKg WeightClassKg  ...  Tested      Country  State  \
# 0  Masters 1         51.90            52  ...     Yes  New Zealand    NaN
# 1       Open         50.64            52  ...     Yes    Australia    NaN
# 2       Open         55.76            56  ...     Yes  New Zealand    NaN
# 3       Open         56.42            60  ...     Yes    Australia    NaN
# 4  Masters 2         58.20            60  ...     Yes  New Zealand    NaN
#
#    Federation  ParentFederation        Date  MeetCountry  MeetState  MeetTown  \
# ...

# %%
PowerLifting.shape
# Out:
# (1179737, 41)

# %%
PowerLifting.head(2)
# Out:
#              Name Sex Event   Equipment   Age AgeClass BirthYearClass  \
# 0   Karen Thomson   F   SBD  Single-ply  39.5    35-39          40-49
# 1  Deborah Groves   F   SBD  Single-ply  30.5    24-34          24-39
#
#     Division  BodyweightKg WeightClassKg  ...  Tested      Country  State  \
# 0  Masters 1         51.90            52  ...     Yes  New Zealand    NaN
# 1       Open         50.64            52  ...     Yes    Australia    NaN
#
#    Federation  ParentFederation        Date  MeetCountry  MeetState  MeetTown  \
# 0   OceaniaPF               IPF  2002-12-06  New Zealand        BOP  Tauranga
# 1   OceaniaPF               IPF  2002-12-06  New Zealand        BOP  Tauranga
#
#                 MeetName
# 0  Oceania Championships
# 1  Oceania Championships
#
# [2 rows x 41 columns]

# %%
PowerLifting['Date'] = pd.to_datetime(PowerLifting['Date'])

# %%
PowerLifting['Month'] = PowerLifting['Date'].apply(lambda x:x.month)
PowerLifting['Year'] = PowerLifting['Date'].apply(lambda x:x.year)

# %%
plt.figure(figsize=(10,7))
PowerLifting['MeetCountry'].value_counts()[:10].sort_values(ascending=True).plot(kind='barh')
plt.title('Meets by Country\n',fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()
print('Meets by Country:\n')
print(PowerLifting['MeetCountry'].value_counts()[:10])
# Out:
# Meets by Country:
#
# USA        356785
# Russia     189314
# Canada      53490
# Norway      45719
# Germany     42010
# Czechia     36977
# Finland     35905
# England     34054
# Ukraine     30114
# Sweden      29603
# Name: MeetCountry, dtype: int64

# %%
plt.figure(figsize=(12,8))
sns.heatmap(PowerLifting.isnull(),cmap='cool',cbar=False,yticklabels=False)
plt.title('Missing Data?',fontsize=20)
plt.show()

# %%
PowerLifting.head()
# Out:
#              Name Sex Event   Equipment   Age AgeClass BirthYearClass  \
# 0   Karen Thomson   F   SBD  Single-ply  39.5    35-39          40-49
# 1  Deborah Groves   F   SBD  Single-ply  30.5    24-34          24-39
# 2     Renee Orbon   F   SBD  Single-ply  31.5    24-34          24-39
# 3  Rikki Flanders   F   SBD  Single-ply  31.5    24-34          24-39
# 4  Julie Hallmond   F   SBD  Single-ply   NaN      NaN          50-59
#
#     Division  BodyweightKg WeightClassKg  ...      Country  State  Federation  \
# 0  Masters 1         51.90            52  ...  New Zealand    NaN   OceaniaPF
# 1       Open         50.64            52  ...    Australia    NaN   OceaniaPF
# 2       Open         55.76            56  ...  New Zealand    NaN   OceaniaPF
# 3       Open         56.42            60  ...    Australia    NaN   OceaniaPF
# 4  Masters 2         58.20            60  ...  New Zealand    NaN   OceaniaPF
#
# ...

# %%
PowerLifting['Name'].value_counts()[:10]
# Out:
# Sverre Paulsen      210
# Erik Rasmussen      204
# Max Bristow         175
# Jackie Blasbery     171
# Bjørn Grønvold      171
# Hana Takáčová       167
# Jenny Hunter        166
# Jean-Luc Collart    166
# Zbyněk Krejča       159
# Kim Dahl Hansen     157
# Name: Name, dtype: int64

# %%
print('Number of unique divisions: ' + str(PowerLifting['Division'].nunique()))
# Out:
# Number of unique divisions: 1009

# %%
def age_class(x):
    if x < 13:
        return 'CHILD'
    if x >= 13 and x <= 17:
        return 'YOUTH'
    if x >= 18 and x <= 34:
        return 'ADULT'
    if x >= 35:
        return 'MASTERS'

# %%
def squatBody(x):
    return x['Best3SquatKg'] / x['BodyweightKg']

def benchBody(x):
    return x['Best3BenchKg'] / x['BodyweightKg']

def deadliftBody(x):
    return x['Best3DeadliftKg'] / x['BodyweightKg']

def totalLiftBody(x):
    return x['TotalKg'] / x['BodyweightKg']

# %%
PowerLifting['Squat / BW'] = PowerLifting.apply(squatBody,axis=1)
PowerLifting['Bench / BW'] = PowerLifting.apply(benchBody,axis=1)
PowerLifting['Deadlift / BW'] = PowerLifting.apply(deadliftBody,axis=1)
PowerLifting['Total / BW'] = PowerLifting.apply(totalLiftBody,axis=1)

# %%
male = PowerLifting[PowerLifting['Sex']=='M']
female = PowerLifting[PowerLifting['Sex']=='F']

# %%
male = df[df['Sex']=='M']
female = df[df['Sex']=='F']

# %%
def male_weight_class(x):
    if x <= 56:
        return '56 Kg'
    if x <= 62 and x > 56:
        return '62 Kg'
    if x <= 69 and x > 62:
        return '69 Kg'
    if x <= 77 and x > 69:
        return '77 Kg'
    if x <= 85 and x > 77:
        return '85 Kg'
    if x <= 94 and x > 85:
        return '94 Kg'
    if x <= 105 and x > 94:
        return '105 Kg'
    if x > 105:
        return '105+ Kg'
        
def female_weight_class(x):
    if x <= 48:
        return '48 Kg'
    if x <= 53 and x > 48:
        return '53 Kg'
    if x <= 58 and x > 53:
        return '58 Kg'
    if x <= 63 and x > 58:
        return '63 Kg'
    if x <= 69 and x > 63:
        return '69 Kg'
    if x <= 75 and x > 69:
        return '75 Kg'
    if x <= 90 and x > 75:
        return '90 Kg'
    if x > 90:
        return '90+ Kg'

# %%
male['WeightClassKg'] = male['BodyweightKg'].apply(male_weight_class)
female['WeightClassKg'] = female['BodyweightKg'].apply(female_weight_class)
# Out:
# /var/folders/r8/sb0l058j0r5_sh7jvqgwwn_40000gn/T/ipykernel_2046/3676673241.py:1: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   male['WeightClassKg'] = male['BodyweightKg'].apply(male_weight_class)
# /var/folders/r8/sb0l058j0r5_sh7jvqgwwn_40000gn/T/ipykernel_2046/3676673241.py:2: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   female['WeightClassKg'] = female['BodyweightKg'].apply(female_weight_class)

# %%
PowerLifting = pd.concat([male,female])

# %%
PowerLifting[PowerLifting['Best3BenchKg']<0].head(3)
# Out:
#                        Name Sex Event   Equipment   Age AgeClass  \
# 1703   Washington Faatauvaa   M   SBD  Single-ply   NaN      NaN
# 35392     Louis Bachfischer   M   SBD         Raw   NaN      NaN
# 35405         Armand Bekker   M   SBD         Raw  30.5    24-34
#
#       BirthYearClass Division  BodyweightKg WeightClassKg  ...   MeetCountry  \
# 1703             NaN     Open         89.65         94 Kg  ...         Samoa
# 35392            NaN     MR-O         81.40         85 Kg  ...  South Africa
# 35405          24-39     MR-O         91.60         94 Kg  ...  South Africa
#
#        MeetState       MeetTown                               MeetName  Month  \
# 1703         NaN           Apia                    South Pacific Games      9
# 35392        NaN  Potchefstroom  SA Classic Powerlifting Championships      4
# 35405        NaN  Potchefstroom  SA Classic Powerlifting Championships      4
#
#        Year  Squat / BW  Bench / BW  Deadlift / BW  Total / BW
# ...

# %%
negative_lifts = len(PowerLifting[(PowerLifting['Best3BenchKg']<0) | (PowerLifting['Best3DeadliftKg']<0) | (PowerLifting['Best3SquatKg']<0)]) / len(PowerLifting)

print('Percent chance of one or more lift values to be negative: {}%'.format(negative_lifts*100))
# Out:
# Percent chance of one or more lift values to be negative: 0.28726936440487605%

# %%
PowerLifting = PowerLifting[(PowerLifting['Best3SquatKg'] > 0) | (PowerLifting['Best3SquatKg'].isnull() == True)]
PowerLifting = PowerLifting[(PowerLifting['Best3DeadliftKg'] > 0) | (PowerLifting['Best3DeadliftKg'].isnull() == True)]
PowerLifting = PowerLifting[(PowerLifting['Best3BenchKg'] > 0) | (PowerLifting['Best3BenchKg'].isnull() == True)]

# %%
plt.figure(figsize=(10,7))
PowerLifting['Sex'].value_counts().plot(kind='bar')
plt.title('Gender Count',fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.show()
print('Percentage of Male lifters: {}%\n'.format(round(len(PowerLifting[PowerLifting['Sex']=='M'])/len(PowerLifting)*100),4))
print(PowerLifting['Sex'].value_counts())
# Out:
# Percentage of Male lifters: 76%
#
# M    888963
# F    287377
# Name: Sex, dtype: int64

# %%
plt.figure(figsize=(10,7))
PowerLifting['Sex'].value_counts().plot(kind='bar')
plt.title('Gender Count',fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.show()
print('Percentage of Male lifters: {}%\n'.format(round(len(PowerLifting[PowerLifting['Sex']=='F'])/len(PowerLifting)*100),4))
print(PowerLifting['Sex'].value_counts())
# Out:
# Percentage of Male lifters: 24%
#
# M    888963
# F    287377
# Name: Sex, dtype: int64

# %%
g = sns.FacetGrid(PL,hue='Sex',aspect=1.5,legend_out=True)
g = g.map(plt.hist,'Age',bins=50,alpha=.5)
plt.title('Lifters Age',fontsize=20)
plt.legend(loc=1)
plt.show()
# Out:
# /usr/local/lib/python3.9/site-packages/seaborn/axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# /usr/local/lib/python3.9/site-packages/seaborn/axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]
# /usr/local/lib/python3.9/site-packages/seaborn/axisgrid.py:745: FutureWarning: iteritems is deprecated and will be removed in a future version. Use .items instead.
#   plot_args = [v for k, v in plot_data.iteritems()]

# %%
PowerLifting[PowerLifting['Age']==10]
# Out:
#                       Name Sex Event Equipment   Age AgeClass BirthYearClass  \
# 168782         Rowan Kratz   M   SBD       Raw  10.0     5-12            NaN
# 171869         Nolan Davis   M   SBD       Raw  10.0     5-12            NaN
# 179769          Jacob Mann   M     B       Raw  10.0     5-12            NaN
# 179869          Jacob Mann   M     D       Raw  10.0     5-12            NaN
# 179955          Jacob Mann   M   SBD       Raw  10.0     5-12            NaN
# ...                    ...  ..   ...       ...   ...      ...            ...
# 257049  Kensington Maizels   F     B       Raw  10.0     5-12            NaN
# 257535  Kensington Maizels   F   SBD       Raw  10.0     5-12            NaN
# 268699     Isabella Martin   F   SBD       Raw  10.0     5-12            NaN
# 273735      Jadyn Shepherd   F   SBD       Raw  10.0     5-12            NaN
# 279308     Celeste Godinez   F   SBD       Raw  10.0     5-12            NaN
#
# ...

# %%
g = sns.FacetGrid(PL,hue='Sex',size=6,aspect=1.5,legend_out=True)
g = g.map(plt.hist,'BodyweightKg',bins=50,alpha=.6)
plt.title('Bodyweight Kg',fontsize=20)
plt.yticks(fontsize=15)
plt.xticks(fontsize=15)
plt.xlabel('BodyweightKg',fontsize=15)
plt.legend(loc=1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [13], in <cell line: 1>()
# ----> 1 g = sns.FacetGrid(PL,hue='Sex',size=6,aspect=1.5,legend_out=True)
#       2 g = g.map(plt.hist,'BodyweightKg',bins=50,alpha=.6)
#       3 plt.title('Bodyweight Kg',fontsize=20)
#
# TypeError: __init__() got an unexpected keyword argument 'size'

# %%
pip install --upgrade gensim
# Out:
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# ...
# DEPRECATION: Configuring installation scheme with distutils config files is deprecated and will no longer work in the near future. If you are using a Homebrew or Linuxbrew Python, please see discussion at https://github.com/Homebrew/homebrew-core/issues/76621
# WARNING: There was an error checking the latest version of pip.
# Note: you may need to restart the kernel to use updated packages.

# %%
conda install -c conda-forge gensim
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Input In [15], in <cell line: 1>()
# ----> 1 get_ipython().run_line_magic('conda', 'install -c conda-forge gensim')
#
# File /usr/local/lib/python3.9/site-packages/IPython/core/interactiveshell.py:2294, in InteractiveShell.run_line_magic(self, magic_name, line, _stack_depth)
#    2292     kwargs['local_ns'] = self.get_local_scope(stack_depth)
#    2293 with self.builtin_trap:
# -> 2294     result = fn(*args, **kwargs)
#    2295 return result
#
# File /usr/local/lib/python3.9/site-packages/IPython/core/magics/packaging.py:87, in PackagingMagics.conda(self, line)
#      81 """Run the conda package manager within the current kernel.
#      82
#      83 Usage:
#      84   %conda install [pkgs]
#      85 """
#      86 if not _is_conda_environment():
# ...

# %%
g = sns.FacetGrid(PL,hue='Sex',size=6,aspect=1.5,legend_out=True)
g = g.map(plt.hist,'Age',bins=50,alpha=.5)
plt.title('Lifters Age',fontsize=20)
plt.legend(loc=1)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [16], in <cell line: 1>()
# ----> 1 g = sns.FacetGrid(PL,hue='Sex',size=6,aspect=1.5,legend_out=True)
#       2 g = g.map(plt.hist,'Age',bins=50,alpha=.5)
#       3 plt.title('Lifters Age',fontsize=20)
#
# TypeError: __init__() got an unexpected keyword argument 'size'

# %%
sns.lmplot(x='BodyweightKg',
           y='BestDeadliftKg',
           data=PL.dropna(),
           hue='Equipment',
           markers='x',
           size=7,
           aspect=2)
plt.title('Best Deadlift by Equipment Used',fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.ylabel('Best3DeadliftKg',fontsize=15)
plt.xlabel('Body3weightKg',fontsize=15)
plt.show()
print('Equipment Used by Lifters:\n')
print(df['Equipment'].dropna().value_counts())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [17], in <cell line: 1>()
# ----> 1 sns.lmplot(x='BodyweightKg',
#       2            y='BestDeadliftKg',
#       3            data=PL.dropna(),
#       4            hue='Equipment',
#       5            markers='x',
#       6            size=7,
#       7            aspect=2)
#       8 plt.title('Best Deadlift by Equipment Used',fontsize=20)
#       9 plt.xticks(fontsize=15)
#
# TypeError: lmplot() got an unexpected keyword argument 'size'

# %%
PL.filter(items=['Name','BodyweightKg','TotalKg','Total / BW','Wilks','Sex'])[PL['Sex']=='F'].sort_values(ascending=False,by='Wilks')[:10]
# Out:
#                         Name  BodyweightKg  TotalKg   Wilks Sex
# 1137122         Carola Garra         62.70    657.5  708.69   F
# 353064          Carola Garra         62.86    655.0  704.63   F
# 1178372  Larysa Soloviova #1         62.50    645.5  697.44   F
# 1165102  Larysa Soloviova #1         62.85    643.0  691.80   F
# 1160205  Larysa Soloviova #1         62.62    638.5  688.87   F
# 1179683  Larysa Soloviova #1         62.99    641.0  688.49   F
# 1144456  Larysa Soloviova #1         62.84    638.0  686.51   F
# 1136807  Larysa Soloviova #1         62.60    636.0  686.34   F
# 1137134          Agata Sitko         76.00    726.0  684.53   F
# 49102      Taylor LaChapelle         62.40    632.5  684.23   F

# %%
PL.filter(items=['Name','BodyweightKg','TotalKg','Total / BW','Wilks','Sex'])[PL['Sex']=='M'].sort_values(ascending=False,by='Wilks')[:10]
# Out:
#                         Name  BodyweightKg  TotalKg   Wilks Sex
# 183391         Blaine Sumner        176.24   1296.0  699.84   M
# 432905         Blaine Sumner        167.51   1271.5  692.21   M
# 430040         Blaine Sumner        170.68   1272.5  690.71   M
# 1178317        Blaine Sumner        175.70   1275.5  689.12   M
# 914450     Sergey Fedosienko         55.15    735.0  679.26   M
# 1138760    Sergey Fedosienko         55.86    742.5  677.59   M
# 927602     Sergey Fedosienko         51.90    687.5  675.99   M
# 1161019    Sergey Fedosienko         55.49    732.5  672.85   M
# 1165053  Andrey Konovalov #1        161.40   1227.5  672.06   M
# 885856     Sergey Fedosienko         58.15    765.0  671.68   M

# %%
sns.lmplot(x='BodyweightKg',
           y='SquatAllometric',
           data=PL,
           hue='Sex',
           size=7)
plt.title('Allometric Squat Score by Sex (with Regression)',fontsize=20)
plt.xlabel('BodyweightKg',fontsize=15)
plt.ylabel('Allometric Squat Score',fontsize=15)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.show()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [21], in <cell line: 1>()
# ----> 1 sns.lmplot(x='BodyweightKg',
#       2            y='SquatAllometric',
#       3            data=PL,
#       4            hue='Sex',
#       5            size=7)
#       6 plt.title('Allometric Squat Score by Sex (with Regression)',fontsize=20)
#       7 plt.xlabel('BodyweightKg',fontsize=15)
#
# TypeError: lmplot() got an unexpected keyword argument 'size'

# %%
sns.lmplot(x='BodyweightKg',
           y='BestSquatKg',
           data=PL.dropna(),
           hue='Equipment',
           markers='x',
           size=7,
           aspect=2)
plt.title('Best Squat by Equipment Used',fontsize=20)
plt.xticks(fontsize=15)
plt.yticks(fontsize=15)
plt.ylabel('BestSquatKg',fontsize=15)
plt.xlabel('BodyweightKg',fontsize=15)
plt.show()
print('Equipment Used by Lifters:\n')
print(PL['Equipment'].dropna().value_counts())
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Input In [32], in <cell line: 1>()
# ----> 1 sns.lmplot(x='BodyweightKg',
#       2            y='BestSquatKg',
#       3            data=PL.dropna(),
#       4            hue='Equipment',
#       5            markers='x',
#       6            size=7,
#       7            aspect=2)
#       8 plt.title('Best Squat by Equipment Used',fontsize=20)
#       9 plt.xticks(fontsize=15)
#
# TypeError: lmplot() got an unexpected keyword argument 'size'

# %%
PL = sns.load_dataset('data_set')
fig, ax = plt.subplots()
colors = {'setosa': 'red', 'versicolor': 'blue', 'virginica': 'green'}
ax.scatter(PL['sepal_length'], df['sepal_width'], c=df['species'].apply(lambda x: colors[x]))
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Input In [1], in <cell line: 1>()
# ----> 1 PL = sns.load_dataset('data_set')
#       2 fig, ax = plt.subplots()
#       3 colors = {'setosa': 'red', 'versicolor': 'blue', 'virginica': 'green'}
#
# NameError: name 'sns' is not defined
